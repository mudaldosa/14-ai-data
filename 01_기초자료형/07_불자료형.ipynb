# %%
# 불자료형은 어떻게 사용할까?

a = True
b = False
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
print(1 == 1)
print(2>1)
print(1>2)
# Out:
# True
# True
# False

# %%
print(bool(1))
print(bool(0))
print(bool(0.1))
print(bool(-1))
print("Python",bool("Python"))
print("",bool(""))
print("[]",bool([]))
print("[]",bool([1,2,3]))
# Out:
#   Cell In[11], line 10
#     via classmethod
#         ^
# SyntaxError: invalid syntax

# %%
if [3>1]:
	print("참")
else:
	print("거짓")
# Out:
# 참

# %%
# 논리연산자
#1. and 연산자

print(True and True)
print(True and False)
print(False and True)

#2. or 연산자
print(True or True)
print(True or False)
print(False or True)

#3. not 연산자
print(not True )
print(not False )
print(not 1 )
print(not [] )
# Out:
# True
# False
# False
# True
# True
# True
# False
# True
# False
# True

# %%
kkkkkkkkkkkkkkkkkkkk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 kkkkkkkkkkkkkkkkkkkk
#
# NameError: name 'kkkkkkkkkkkkkkkkkkkk' is not defined
