# %%
# 8진수와 16진수
a = 0x8ff
a
# Out:
# 2303

# %%
#사칙연산
a = 3
b = 4

print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 7
# -1
# 12
# 0.75

# %%
a = 3
b = 4

a ** b
# Out:
# 81

# %%
16 ** 0.5
# Out:
# 4.0

# %%
#나눗셈 후 나머지를 반환하는 % 연산자
7 % 3
# Out:
# 1

# %%
# 나눗셈 후 몫을 반환하는 // 연산자
7 // 3
# Out:
# 2

# %%
# 복합연산자
a = 1
a = a + 1
a
# Out:
# 2

# %%
a = 1
a += 1 
a -= 1
a *= 1
a /= 1
# Out:
# 2
